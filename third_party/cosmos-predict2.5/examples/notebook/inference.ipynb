# %% [markdown]
# # Predict Inference (single GPU)

# %%
import os
from pathlib import Path

# 替换为你系统上 CUDA 12.8 的实际安装路径，通常是 /usr/local/cuda-12.8
cuda_path = "/usr/local/cuda-12.8"

os.environ["CUDA_HOME"] = cuda_path
os.environ["PATH"] = f"{cuda_path}/bin:" + os.environ.get("PATH", "")
os.environ["LD_LIBRARY_PATH"] = f"{cuda_path}/lib64:" + os.environ.get("LD_LIBRARY_PATH", "")


output_dir = Path("outputs")

if not (Path.cwd() / "cosmos_predict2").is_dir():
    os.chdir(Path.cwd().parent.parent)  # Change working directory to root
    assert (Path.cwd() / "cosmos_predict2").is_dir(), "Working directory change failed."

os.environ["PYTHONPATH"] = str(os.getcwd())

# %% [markdown]
# to use pre-trained checkpoints just specify the model

# %%
from cosmos_predict2.config import SetupArguments

setup_args = SetupArguments(
    context_parallel_size=1,
    output_dir=output_dir,
    model="2B/pre-trained",
    keep_going=True,
    experiment="predict2_video2world_training_2b_cosmos_nemo_assets",
    disable_guardrails=True,
)
# Out:
# [01-19 14:54:25|INFO|cosmos_predict2/_src/imaginaire/utils/checkpoint_db.py:192:path] Downloading checkpoint nvidia/Cosmos-Predict2.5-2B/base/pre-trained(d20b7120-df3e-4911-919d-db6e08bad31c)
# [01-19 14:54:25|INFO|cosmos_predict2/_src/imaginaire/utils/checkpoint_db.py:96:_download] Downloading checkpoint file from Hugging Face with {'repo_id': 'nvidia/Cosmos-Predict2.5-2B', 'repo_type': 'model', 'revision': '15a82a2ec231bc318692aa0456a36537c806e7d4', 'filename': 'base/pre-trained/d20b7120-df3e-4911-919d-db6e08bad31c_ema_bf16.pt'}

# %% [markdown]
# to use a local checkpoint from post-training specify the checkpoint

# %%
from cosmos_predict2.config import SetupArguments

checkpoint_path = "/data/LFT-W02_data/junjie/weights/Cosmos-Predict2.5-2B/base/post-trained/81edfebe-bd6a-4039-8c1d-737df1a790bf_ema_bf16.pt"

setup_args = SetupArguments(
    checkpoint_path=checkpoint_path,
    context_parallel_size=1,
    output_dir=output_dir,
    model="2B/pre-trained",
    keep_going=True,
    experiment="predict2_video2world_training_2b_cosmos_nemo_assets",
    disable_guardrails=True,
)

# %%
from cosmos_predict2.inference import Inference

pipe = Inference(setup_args)
# Out:
# [01-19 15:41:25|INFO|cosmos_predict2/_src/predict2/datasets/augmentor_provider.py:94:augmentor_register] registering video_basic_augmentor_v1...
# [01-19 15:41:25|INFO|cosmos_predict2/_src/predict2/datasets/augmentor_provider.py:94:augmentor_register] registering video_basic_augmentor_v2...
# [01-19 15:41:25|INFO|cosmos_predict2/_src/predict2/datasets/augmentor_provider.py:94:augmentor_register] registering noframedrop_nocameramove_video_augmentor_v1...
# [01-19 15:41:25|INFO|cosmos_predict2/_src/predict2/datasets/augmentor_provider.py:94:augmentor_register] registering nocameramove_video_augmentor_v1...
# [01-19 15:41:25|INFO|cosmos_predict2/_src/predict2/datasets/augmentor_provider.py:94:augmentor_register] registering image_basic_augmentor...
# [01-19 15:41:25|INFO|cosmos_predict2/_src/predict2/datasets/augmentor_provider.py:94:augmentor_register] registering image_basic_augmentor_without_embeddings...
# [01-19 15:41:26|CRITICAL|cosmos_predict2/_src/imaginaire/utils/config_helper.py:192:import_all_modules_from_package] Reloading all modules from package cosmos_predict2._src.predict2.configs.video2world.experiment
# [01-19 15:41:29|INFO|cosmos_predict2/_src/predict2/configs/video2world/experiment/specialized_model/SFT_2B_RF.py:853:<module>] Storing Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_face
# [01-19 15:41:29|INFO|cosmos_predict2/_src/predict2/configs/video2world/experiment/specialized_model/SFT_2B_RF.py:853:<module>] Storing Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_crowded
# [01-19 15:41:29|INFO|cosmos_predict2/_src/predict2/configs/video2world/experiment/specialized_model/SFT_2B_RF.py:853:<module>] Storing Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_high_motion
# [01-19 15:41:29|INFO|cosmos_predict2/_src/predict2/configs/video2world/experiment/specialized_model/SFT_2B_RF.py:853:<module>] Storing Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_robotics
# [01-19 15:41:29|INFO|cosmos_predict2/_src/predict2/configs/video2world/experiment/specialized_model/SFT_2B_RF.py:853:<module>] Storing Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_av
# [01-19 15:41:29|INFO|cosmos_predict2/_src/predict2/configs/video2world/experiment/specialized_model/SFT_2B_RF.py:853:<module>] Storing Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_physical_ai
# [01-19 15:41:29|INFO|cosmos_predict2/_src/predict2/configs/video2world/experiment/specialized_model/SFT_2B_RF.py:853:<module>] Storing Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_4k_cooldown
# [01-19 15:41:29|INFO|cosmos_predict2/_src/predict2/configs/video2world/experiment/specialized_model/SFT_2B_RF.py:853:<module>] Storing Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_face_only2
# [01-19 15:41:29|INFO|cosmos_predict2/_src/predict2/configs/video2world/experiment/specialized_model/SFT_2B_RF.py:853:<module>] Storing Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_crowded_only2
# [01-19 15:41:29|INFO|cosmos_predict2/_src/predict2/configs/video2world/experiment/specialized_model/SFT_2B_RF.py:853:<module>] Storing Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_high_motion_only2
# [01-19 15:41:29|INFO|cosmos_predict2/_src/predict2/configs/video2world/experiment/specialized_model/SFT_2B_RF.py:853:<module>] Storing Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_robotics_only2
# [01-19 15:41:29|INFO|cosmos_predict2/_src/predict2/configs/video2world/experiment/specialized_model/SFT_2B_RF.py:853:<module>] Storing Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_av_only2
# [01-19 15:41:29|INFO|cosmos_predict2/_src/predict2/configs/video2world/experiment/specialized_model/SFT_2B_RF.py:853:<module>] Storing Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_physical_ai_only2
# [01-19 15:41:29|INFO|cosmos_predict2/_src/predict2/configs/video2world/experiment/specialized_model/SFT_2B_RF.py:853:<module>] Storing Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_4k_cooldown_only2
# [01-19 15:41:29|INFO|cosmos_predict2/_src/predict2/configs/video2world/experiment/specialized_model/SFT_2B_RF.py:853:<module>] Storing Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_face_high_sigma
# [01-19 15:41:29|INFO|cosmos_predict2/_src/predict2/configs/video2world/experiment/specialized_model/SFT_2B_RF.py:853:<module>] Storing Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_crowded_high_sigma
# [01-19 15:41:29|INFO|cosmos_predict2/_src/predict2/configs/video2world/experiment/specialized_model/SFT_2B_RF.py:853:<module>] Storing Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_high_motion_high_sigma
# [01-19 15:41:29|INFO|cosmos_predict2/_src/predict2/configs/video2world/experiment/specialized_model/SFT_2B_RF.py:853:<module>] Storing Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_robotics_high_sigma
# [01-19 15:41:29|INFO|cosmos_predict2/_src/predict2/configs/video2world/experiment/specialized_model/SFT_2B_RF.py:853:<module>] Storing Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_av_high_sigma
# [01-19 15:41:29|INFO|cosmos_predict2/_src/predict2/configs/video2world/experiment/specialized_model/SFT_2B_RF.py:853:<module>] Storing Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_physical_ai_high_sigma
# [01-19 15:41:29|INFO|cosmos_predict2/_src/predict2/configs/video2world/experiment/specialized_model/SFT_2B_RF.py:853:<module>] Storing Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_4k_cooldown_high_sigma
# [01-19 15:41:29|INFO|cosmos_predict2/_src/predict2/configs/video2world/experiment/specialized_model/SFT_2B_RF.py:853:<module>] Storing Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_face_high_sigma2
# [01-19 15:41:29|INFO|cosmos_predict2/_src/predict2/configs/video2world/experiment/specialized_model/SFT_2B_RF.py:853:<module>] Storing Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_crowded_high_sigma2
# [01-19 15:41:29|INFO|cosmos_predict2/_src/predict2/configs/video2world/experiment/specialized_model/SFT_2B_RF.py:853:<module>] Storing Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_robotics_high_sigma2
# [01-19 15:41:29|INFO|cosmos_predict2/_src/predict2/configs/video2world/experiment/specialized_model/SFT_2B_RF.py:853:<module>] Storing Stage-c_pt_4-Index-2-Size-2B-Res-720-Fps-16-Note-rf_with_edm_ckpt
# [01-19 15:41:29|CRITICAL|cosmos_predict2/_src/imaginaire/utils/config_helper.py:192:import_all_modules_from_package] Reloading all modules from package cosmos_predict2.experiments
# [01-19 15:41:29|INFO|cosmos_predict2/_src/imaginaire/utils/checkpoint_db.py:192:path] Downloading checkpoint nvidia/Cosmos-Predict2.5-2B/base/post-trained(81edfebe-bd6a-4039-8c1d-737df1a790bf)
# [01-19 15:41:29|INFO|cosmos_predict2/_src/imaginaire/utils/checkpoint_db.py:96:_download] Downloading checkpoint file from Hugging Face with {'repo_id': 'nvidia/Cosmos-Predict2.5-2B', 'repo_type': 'model', 'revision': '15a82a2ec231bc318692aa0456a36537c806e7d4', 'filename': 'base/post-trained/81edfebe-bd6a-4039-8c1d-737df1a790bf_ema_bf16.pt'}
# [01-19 15:41:29|INFO|cosmos_predict2/_src/imaginaire/utils/checkpoint_db.py:192:path] Downloading checkpoint nvidia/Cosmos-Predict2.5-2B/base/pre-trained(d20b7120-df3e-4911-919d-db6e08bad31c)
# [01-19 15:41:29|INFO|cosmos_predict2/_src/imaginaire/utils/checkpoint_db.py:96:_download] Downloading checkpoint file from Hugging Face with {'repo_id': 'nvidia/Cosmos-Predict2.5-2B', 'repo_type': 'model', 'revision': '15a82a2ec231bc318692aa0456a36537c806e7d4', 'filename': 'base/pre-trained/d20b7120-df3e-4911-919d-db6e08bad31c_ema_bf16.pt'}
# [01-19 15:41:29|INFO|cosmos_predict2/_src/imaginaire/utils/checkpoint_db.py:192:path] Downloading checkpoint nvidia/Cosmos-Predict2.5-14B/base/pre-trained(54937b8c-29de-4f04-862c-e67b04ec41e8)
# [01-19 15:41:29|INFO|cosmos_predict2/_src/imaginaire/utils/checkpoint_db.py:96:_download] Downloading checkpoint file from Hugging Face with {'repo_id': 'nvidia/Cosmos-Predict2.5-14B', 'repo_type': 'model', 'revision': '03eb354f35eae0d6e0c1be3c9f94d8551e125570', 'filename': 'base/pre-trained/54937b8c-29de-4f04-862c-e67b04ec41e8_ema_bf16.pt'}
# ---------------------------------------------------------------------------
# MissingConfigException                    Traceback (most recent call last)
# Cell In[4], line 3
#       1 from cosmos_predict2.inference import Inference
# ----> 3 pipe = Inference(setup_args)
#
# File /data/LFT-W02_data/junjie/cosmos-predict2.5/cosmos_predict2/inference.py:39, in Inference.__init__(self, args)
#      37 if args.model_key.distilled:
#      38     experiment_opts.append("model.config.init_student_with_teacher=False")
# ---> 39 self.pipe = Video2WorldInference(
#      40     # pyrefly: ignore  # bad-argument-type
#      41     experiment_name=args.experiment,
#      42     # pyrefly: ignore  # bad-argument-type
#      43     ckpt_path=args.checkpoint_path,
#      44     s3_credential_path="",
#      45     # pyrefly: ignore  # bad-argument-type
#      46     context_parallel_size=args.context_parallel_size,
#      47     config_file=args.config_file,
#      48     experiment_opts=experiment_opts,
#      49     offload_diffusion_model=args.offload_diffusion_model,
#      50     offload_text_encoder=args.offload_text_encoder,
#      51     offload_tokenizer=args.offload_tokenizer,
#      52 )
#      53 if self.rank0:
#      54     args.output_dir.mkdir(parents=True, exist_ok=True)
#
# File /data/LFT-W02_data/junjie/cosmos-predict2.5/cosmos_predict2/_src/predict2/inference/video2world.py:294, in Video2WorldInference.__init__(self, experiment_name, ckpt_path, s3_credential_path, context_parallel_size, config_file, experiment_opts, offload_diffusion_model, offload_text_encoder, offload_tokenizer)
#     291 if self.offload_diffusion_model:
#     292     os.environ["COSMOS_PREDICT2_OFFLOAD_DIT"] = "1"
# --> 294 model, config = load_model_from_checkpoint(
#     295     experiment_name=self.experiment_name,
#     296     s3_checkpoint_dir=self.ckpt_path,
#     297     config_file=config_file,
#     298     load_ema_to_reg=True,
#     299     experiment_opts=experiment_opts,
#     300     to_device=model_device,
#     301 )
#     303 # By default, everything will be constructed directly on the GPU (except DiT)
#     304 # Handle offloading options at inference entry
#     305
#     306 # [On-entry offloading part 1]: DiT was offloaded as default by the lazy ctor
#     307 # Offload or reload according to setup
#     308 if self.offload_diffusion_model:
#
# File /data/LFT-W02_data/junjie/cosmos-predict2.5/cosmos_predict2/_src/predict2/utils/model_loader.py:87, in load_model_from_checkpoint(experiment_name, s3_checkpoint_dir, config_file, enable_fsdp, load_ema_to_reg, instantiate_ema, seed, local_cache_dir, override_cache, experiment_opts, skip_load_model, adapter_checkpoint_paths, cache_text_encoder, to_device)
#      85 config_module = get_config_module(config_file)
#      86 config = importlib.import_module(config_module).make_config()
# ---> 87 config = override(config, ["--", f"experiment={experiment_name}"] + experiment_opts)
#      89 # Override checkpoint path if provided
#      90 if s3_checkpoint_dir:
#
# File /data/LFT-W02_data/junjie/cosmos-predict2.5/cosmos_predict2/_src/imaginaire/utils/config_helper.py:97, in override(config, overrides, remove_defaults)
#      95 if not GlobalHydra().is_initialized():
#      96     with initialize(version_base=None):
# ---> 97         config_omegaconf = compose(config_name="config", overrides=overrides)
#      98         OmegaConf.resolve(config_omegaconf)
#      99 else:
#
# File /data/LFT-W02_data/junjie/cosmos-predict2.5/.venv/lib/python3.10/site-packages/hydra/compose.py:38, in compose(config_name, overrides, return_hydra_config, strict)
#      36 gh = GlobalHydra.instance()
#      37 assert gh.hydra is not None
# ---> 38 cfg = gh.hydra.compose_config(
#      39     config_name=config_name,
#      40     overrides=overrides,
#      41     run_mode=RunMode.RUN,
#      42     from_shell=False,
#      43     with_log_configuration=False,
#      44 )
#      45 assert isinstance(cfg, DictConfig)
#      47 if not return_hydra_config:
#
# File /data/LFT-W02_data/junjie/cosmos-predict2.5/.venv/lib/python3.10/site-packages/hydra/_internal/hydra.py:594, in Hydra.compose_config(self, config_name, overrides, run_mode, with_log_configuration, from_shell, validate_sweep_overrides)
#     576 def compose_config(
#     577     self,
#     578     config_name: Optional[str],
#    (...)
#     583     validate_sweep_overrides: bool = True,
#     584 ) -> DictConfig:
#     585     """
#     586     :param config_name:
#     587     :param overrides:
#    (...)
#     591     :return:
#     592     """
# --> 594     cfg = self.config_loader.load_configuration(
#     595         config_name=config_name,
#     596         overrides=overrides,
#     597         run_mode=run_mode,
#     598         from_shell=from_shell,
#     599         validate_sweep_overrides=validate_sweep_overrides,
#     600     )
#     601     if with_log_configuration:
#     602         configure_log(cfg.hydra.hydra_logging, cfg.hydra.verbose)
#
# File /data/LFT-W02_data/junjie/cosmos-predict2.5/.venv/lib/python3.10/site-packages/hydra/_internal/config_loader_impl.py:142, in ConfigLoaderImpl.load_configuration(self, config_name, overrides, run_mode, from_shell, validate_sweep_overrides)
#     133 def load_configuration(
#     134     self,
#     135     config_name: Optional[str],
#    (...)
#     139     validate_sweep_overrides: bool = True,
#     140 ) -> DictConfig:
#     141     try:
# --> 142         return self._load_configuration_impl(
#     143             config_name=config_name,
#     144             overrides=overrides,
#     145             run_mode=run_mode,
#     146             from_shell=from_shell,
#     147             validate_sweep_overrides=validate_sweep_overrides,
#     148         )
#     149     except OmegaConfBaseException as e:
#     150         raise ConfigCompositionException().with_traceback(sys.exc_info()[2]) from e
#
# File /data/LFT-W02_data/junjie/cosmos-predict2.5/.venv/lib/python3.10/site-packages/hydra/_internal/config_loader_impl.py:253, in ConfigLoaderImpl._load_configuration_impl(self, config_name, overrides, run_mode, from_shell, validate_sweep_overrides)
#     248 if validate_sweep_overrides:
#     249     self.validate_sweep_overrides_legal(
#     250         overrides=parsed_overrides, run_mode=run_mode, from_shell=from_shell
#     251     )
# --> 253 defaults_list = create_defaults_list(
#     254     repo=caching_repo,
#     255     config_name=config_name,
#     256     overrides_list=parsed_overrides,
#     257     prepend_hydra=True,
#     258     skip_missing=run_mode == RunMode.MULTIRUN,
#     259 )
#     261 config_overrides = defaults_list.config_overrides
#     263 cfg = self._compose_config_from_defaults_list(
#     264     defaults=defaults_list.defaults, repo=caching_repo
#     265 )
#
# File /data/LFT-W02_data/junjie/cosmos-predict2.5/.venv/lib/python3.10/site-packages/hydra/_internal/defaults_list.py:745, in create_defaults_list(repo, config_name, overrides_list, prepend_hydra, skip_missing)
#     736 """
#     737 :param repo:
#     738 :param config_name:
#    (...)
#     742 :return:
#     743 """
#     744 overrides = Overrides(repo=repo, overrides_list=overrides_list)
# --> 745 defaults, tree = _create_defaults_list(
#     746     repo,
#     747     config_name,
#     748     overrides,
#     749     prepend_hydra=prepend_hydra,
#     750     skip_missing=skip_missing,
#     751 )
#     752 overrides.ensure_overrides_used()
#     753 overrides.ensure_deletions_used()
#
# File /data/LFT-W02_data/junjie/cosmos-predict2.5/.venv/lib/python3.10/site-packages/hydra/_internal/defaults_list.py:715, in _create_defaults_list(repo, config_name, overrides, prepend_hydra, skip_missing)
#     706 def _create_defaults_list(
#     707     repo: IConfigRepository,
#     708     config_name: Optional[str],
#    (...)
#     711     skip_missing: bool,
#     712 ) -> Tuple[List[ResultDefault], DefaultsTreeNode]:
#     713     root = _create_root(config_name=config_name, with_hydra=prepend_hydra)
# --> 715     defaults_tree = _create_defaults_tree(
#     716         repo=repo,
#     717         root=root,
#     718         overrides=overrides,
#     719         is_root_config=True,
#     720         interpolated_subtree=False,
#     721         skip_missing=skip_missing,
#     722     )
#     724     output = _tree_to_list(tree=defaults_tree)
#     725     ensure_no_duplicates_in_list(output)
#
# File /data/LFT-W02_data/junjie/cosmos-predict2.5/.venv/lib/python3.10/site-packages/hydra/_internal/defaults_list.py:356, in _create_defaults_tree(repo, root, is_root_config, skip_missing, interpolated_subtree, overrides)
#     348 def _create_defaults_tree(
#     349     repo: IConfigRepository,
#     350     root: DefaultsTreeNode,
#    (...)
#     354     overrides: Overrides,
#     355 ) -> DefaultsTreeNode:
# --> 356     ret = _create_defaults_tree_impl(
#     357         repo=repo,
#     358         root=root,
#     359         is_root_config=is_root_config,
#     360         skip_missing=skip_missing,
#     361         interpolated_subtree=interpolated_subtree,
#     362         overrides=overrides,
#     363     )
#     365     return ret
#
# File /data/LFT-W02_data/junjie/cosmos-predict2.5/.venv/lib/python3.10/site-packages/hydra/_internal/defaults_list.py:457, in _create_defaults_tree_impl(repo, root, is_root_config, skip_missing, interpolated_subtree, overrides)
#     455 if parent.is_virtual():
#     456     if is_root_config:
# --> 457         return _expand_virtual_root(repo, root, overrides, skip_missing)
#     458     else:
#     459         return root
#
# File /data/LFT-W02_data/junjie/cosmos-predict2.5/.venv/lib/python3.10/site-packages/hydra/_internal/defaults_list.py:280, in _expand_virtual_root(repo, root, overrides, skip_missing)
#     277 new_root = DefaultsTreeNode(node=d, parent=root)
#     278 d.update_parent("", "")
# --> 280 subtree = _create_defaults_tree_impl(
#     281     repo=repo,
#     282     root=new_root,
#     283     is_root_config=d.primary,
#     284     skip_missing=skip_missing,
#     285     interpolated_subtree=False,
#     286     overrides=overrides,
#     287 )
#     288 if subtree.children is None:
#     289     children.append(d)
#
# File /data/LFT-W02_data/junjie/cosmos-predict2.5/.venv/lib/python3.10/site-packages/hydra/_internal/defaults_list.py:573, in _create_defaults_tree_impl(repo, root, is_root_config, skip_missing, interpolated_subtree, overrides)
#     570                 continue
#     572             new_root = DefaultsTreeNode(node=d, parent=root)
# --> 573             add_child(children, new_root)
#     575 # processed deferred interpolations
#     576 known_choices = _create_interpolation_map(overrides, defaults_list, self_added)
#
# File /data/LFT-W02_data/junjie/cosmos-predict2.5/.venv/lib/python3.10/site-packages/hydra/_internal/defaults_list.py:520, in _create_defaults_tree_impl.<locals>.add_child(child_list, new_root_)
#     516 def add_child(
#     517     child_list: List[Union[InputDefault, DefaultsTreeNode]],
#     518     new_root_: DefaultsTreeNode,
#     519 ) -> None:
# --> 520     subtree_ = _create_defaults_tree_impl(
#     521         repo=repo,
#     522         root=new_root_,
#     523         is_root_config=False,
#     524         interpolated_subtree=interpolated_subtree,
#     525         skip_missing=skip_missing,
#     526         overrides=overrides,
#     527     )
#     528     if subtree_.children is None:
#     529         child_list.append(new_root_.node)
#
# File /data/LFT-W02_data/junjie/cosmos-predict2.5/.venv/lib/python3.10/site-packages/hydra/_internal/defaults_list.py:488, in _create_defaults_tree_impl(repo, root, is_root_config, skip_missing, interpolated_subtree, overrides)
#     486         parent.deleted = True
#     487         return root
# --> 488     config_not_found_error(repo=repo, tree=root)
#     490 assert loaded is not None
#     491 defaults_list = copy.deepcopy(loaded.defaults_list)
#
# File /data/LFT-W02_data/junjie/cosmos-predict2.5/.venv/lib/python3.10/site-packages/hydra/_internal/defaults_list.py:799, in config_not_found_error(repo, tree)
#     796 lines = "\n".join(descs)
#     797 msg += "\nConfig search path:" + f"\n{lines}"
# --> 799 raise MissingConfigException(
#     800     missing_cfg_file=element.get_config_path(),
#     801     message=msg,
#     802     options=options,
#     803 )
#
# MissingConfigException: In 'config': Could not find 'experiment/predict2_lora_training_2b_cosmos_nemo_assets'
#
# Available options in 'experiment':
# 	I2V_STAGE_C_PT_4_INDEX_00_SIZE_14B_RES_480_FPS16_PROFILING
# 	Stage-a_pt_3-Index-1-Size-2B-Res-480-Fps-16-Note-qwen_imagecaption
# 	Stage-a_pt_3-Index-1-Size-2B-Res-480-Fps-16-Note-qwen_imagecaption_mock_wo_resume
# 	Stage-a_pt_3-Index-1-Size-2B-Res-480-Fps-16-Note-qwen_imagecaption_wo_resume
# 	Stage-a_pt_3-Index-4-Size-14B-Res-480-Fps-16-Note-qwen_imagecaption_sync_noise
# 	Stage-a_pt_3-Index-4-Size-14B-Res-480-Fps-16-Note-qwen_imagecaption_sync_noise_mock_wo_resume
# 	Stage-a_pt_3-Index-4-Size-14B-Res-480-Fps-16-Note-qwen_imagecaption_sync_noise_wo_resume
# 	Stage-a_pt_3-Video2World-Index-1-Size-2B-Res-480-Fps-16-Note-qwen_imagecaption_sync_noise_joint_2framecond
# 	Stage-a_pt_3-Video2World-Index-1-Size-2B-Res-480-Fps-16-Note-qwen_imagecaption_sync_noise_joint_2framecond_mock_wo_resume
# 	Stage-a_pt_3-Video2World-Index-1-Size-2B-Res-480-Fps-16-Note-qwen_imagecaption_sync_noise_joint_2framecond_wo_resume
# 	Stage-a_pt_3-Video2World-Index-2-Size-2B-Res-480-Fps-16-Note-qwen_imagecaption_sync_noise_joint_2framecond_gradaccm_1
# 	Stage-a_pt_3-Video2World-Index-2-Size-2B-Res-480-Fps-16-Note-qwen_imagecaption_sync_noise_joint_2framecond_gradaccm_1_mock_wo_resume
# 	Stage-a_pt_3-Video2World-Index-2-Size-2B-Res-480-Fps-16-Note-qwen_imagecaption_sync_noise_joint_2framecond_gradaccm_1_wo_resume
# 	Stage-a_pt_3-Video2World-Index-4-Size-14B-Res-480-Fps-16-Note-qwen_imagecaption_sync_noise_joint_2framecond
# 	Stage-a_pt_3-Video2World-Index-4-Size-14B-Res-480-Fps-16-Note-qwen_imagecaption_sync_noise_joint_2framecond_mock_wo_resume
# 	Stage-a_pt_3-Video2World-Index-4-Size-14B-Res-480-Fps-16-Note-qwen_imagecaption_sync_noise_joint_2framecond_wo_resume
# 	Stage-a_pt_3-Video2World-Index-5-Size-14B-Res-480-Fps-16-Note-qwen_imagecaption_sync_noise_joint_2framecond
# 	Stage-a_pt_3-Video2World-Index-5-Size-14B-Res-480-Fps-16-Note-qwen_imagecaption_sync_noise_joint_2framecond_mock_wo_resume
# 	Stage-a_pt_3-Video2World-Index-5-Size-14B-Res-480-Fps-16-Note-qwen_imagecaption_sync_noise_joint_2framecond_wo_resume
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_4k_cooldown
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_4k_cooldown_high_sigma
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_4k_cooldown_high_sigma_variant1
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_4k_cooldown_only2
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_4k_cooldown_only2_variant1
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_4k_cooldown_variant1
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_av
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_av_high_sigma
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_av_high_sigma_variant1
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_av_only2
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_av_only2_variant1
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_av_variant1
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_crowded
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_crowded_high_sigma
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_crowded_high_sigma2
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_crowded_high_sigma2_variant1
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_crowded_high_sigma_variant1
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_crowded_only2
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_crowded_only2_variant1
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_crowded_variant1
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_face
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_face_high_sigma
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_face_high_sigma2
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_face_high_sigma2_variant1
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_face_high_sigma_variant1
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_face_only2
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_face_only2_variant1
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_face_variant1
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_high_motion
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_high_motion_high_sigma
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_high_motion_high_sigma_variant1
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_high_motion_only2
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_high_motion_only2_variant1
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_high_motion_variant1
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_physical_ai
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_physical_ai_high_sigma
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_physical_ai_high_sigma_variant1
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_physical_ai_only2
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_physical_ai_only2_variant1
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_physical_ai_variant1
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_robotics
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_robotics_high_sigma
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_robotics_high_sigma2
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_robotics_high_sigma2_variant1
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_robotics_high_sigma_variant1
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_robotics_only2
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_robotics_only2_variant1
# 	Stage-c_pt_4-Index-1-Size-2B-Res-720-Fps-16-Note-rf_robotics_variant1
# 	Stage-c_pt_4-Index-10-Size-14B-Res-480-Fps-16-Note-video_data1pt3_continue_64n
# 	Stage-c_pt_4-Index-10-Size-14B-Res-480-Fps-16-Note-video_data1pt3_continue_64n_mock_wo_resume
# 	Stage-c_pt_4-Index-10-Size-14B-Res-480-Fps-16-Note-video_data1pt3_continue_64n_wo_resume
# 	Stage-c_pt_4-Index-10-Size-2B-Res-480p-Fps-16-Note-05_22_pretrain2pt2_hq_wan
# 	Stage-c_pt_4-Index-10-Size-2B-Res-480p-Fps-16-Note-05_22_pretrain2pt2_hq_wan_mock_wo_resume
# 	Stage-c_pt_4-Index
Size-2B-Res-720-Fps-16-Note-HQ_V7_human_only_high_motion
# 	Stage-c_pt_4-Index-4-Size-2B-Res-720-Fps-16-Note-HQ_V7_human_only_high_motion_formal
# 	Stage-c_pt_4-Index-4-Size-2B-Res-720-Fps-16-Note-HQ_V7_human_only_high_motion_formal_variant1
# 	Stage-c_pt_4-Index-4-Size-2B-Res-720-Fps-16-Note-HQ_V7_human_only_high_motion_variant1
# 	Stage-c_pt_4-Index-40-Size-14B-Res-720-Fps-16-Note-T24_HQV3pt1_from_38
# 	Stage-c_pt_4-Index-40-Size-14B-Res-720-Fps-16-Note-T24_HQV3pt1_from_38_mock_wo_resume
# 	Stage-c_pt_4-Index-40-Size-14B-Res-720-Fps-16-Note-T24_HQV3pt1_from_38_wo_resume
# 	Stage-c_pt_4-Index-401-Size-2B-Res-720-Fps-16-Note-HQ_V7_physical_ai
# 	Stage-c_pt_4-Index-401-Size-2B-Res-720-Fps-16-Note-HQ_V7_physical_ai_formal
# 	Stage-c_pt_4-Index-401-Size-2B-Res-720-Fps-16-Note-HQ_V7_physical_ai_formal_variant1
# 	Stage-c_pt_4-Index-401-Size-2B-Res-720-Fps-16-Note-HQ_V7_physical_ai_variant1
# 	Stage-c_pt_4-Index-41-Size-14B-Res-720-Fps-16-Note-T24_HQV3pt1_1080_from_40
# 	Stage-c_pt_4-Index-41-Size-14B-Res-720-Fps-16-Note-T24_HQV3pt1_1080_from_40_mock_wo_resume
# 	Stage-c_pt_4-Index-41-Size-14B-Res-720-Fps-16-Note-T24_HQV3pt1_1080_from_40_wo_resume
# 	Stage-c_pt_4-Index-42-Size-14B-Res-720-Fps-16-Note-T24_HQV4_1080_from_40
# 	Stage-c_pt_4-Index-42-Size-14B-Res-720-Fps-16-Note-T24_HQV4_1080_from_40_mock_wo_resume
# 	Stage-c_pt_4-Index-42-Size-14B-Res-720-Fps-16-Note-T24_HQV4_1080_from_40_wo_resume
# 	Stage-c_pt_4-Index-43-Size-14B-Res-720-Fps-16-Note-T24_HQV5_from_40
# 	Stage-c_pt_4-Index-43-Size-14B-Res-720-Fps-16-Note-T24_HQV5_from_40_mock_wo_resume
# ...
# 	Stage-c_pt_4-reason_embeddings-Index-26-Size-2B-Res-720-Fps-16-Note-HQ_V6_from_22_qwen_concat_wd_high_sigma_loss_reweighted_v3_general_cp4
# 	Stage-c_pt_4-reason_embeddings-Index-26-Size-2B-Res-720-Fps-16-Note-HQ_V6_from_22_qwen_concat_wd_high_sigma_loss_reweighted_v3_general_cp4_mock_wo_resume
# 	Stage-c_pt_4-reason_embeddings-Index-26-Size-2B-Res-720-Fps-16-Note-HQ_V6_from_22_qwen_concat_wd_high_sigma_loss_reweighted_v3_general_cp4_wo_resume
# 	Stage-c_pt_4-reason_embeddings-Index-26-Size-2B-Res-720-Fps-16-Note-HQ_V6_from_22_qwen_concat_wd_high_sigma_loss_reweighted_v4_av_cp4
# 	Stage-c_pt_4-reason_embeddings-Index-26-Size-2B-Res-720-Fps-16-Note-HQ_V6_from_22_qwen_concat_wd_high_sigma_loss_reweighted_v4_av_cp4_mock_wo_resume
# 	Stage-c_pt_4-reason_embeddings-Index-26-Size-2B-Res-720-Fps-16-Note-HQ_V6_from_22_qwen_concat_wd_high_sigma_loss_reweighted_v4_av_cp4_wo_resume
# 	Stage-c_pt_4-reason_embeddings-Index-26-Size-2B-Res-720-Fps-16-Note-HQ_V6_from_22_qwen_concat_wd_high_sigma_loss_reweighted_v4_general_cp4
# 	Stage-c_pt_4-reason_embeddings-Index-26-Size-2B-Res-720-Fps-16-Note-HQ_V6_from_22_qwen_concat_wd_high_sigma_loss_reweighted_v4_general_cp4_mock_wo_resume
# 	Stage-c_pt_4-reason_embeddings-Index-26-Size-2B-Res-720-Fps-16-Note-HQ_V6_from_22_qwen_concat_wd_high_sigma_loss_reweighted_v4_general_cp4_wo_resume
# 	Stage-c_pt_4-reason_embeddings-Index-26-Size-2B-Res-720-Fps-16-Note-HQ_V6_from_22_qwen_concat_wd_high_sigma_loss_reweighted_wo_resume
# 	Stage-c_pt_4-reason_embeddings-Index-26-Size-2B-Res-720-Fps-16-Note-HQ_V6_from_22_qwen_concat_wd_high_sigma_mock_wo_resume
# 	Stage-c_pt_4-reason_embeddings-Index-26-Size-2B-Res-720-Fps-16-Note-HQ_V6_from_22_qwen_concat_wd_high_sigma_wo_resume
# 	Stage-c_pt_4-reason_embeddings-Index-26-Size-2B-Res-720-Fps-16-Note-HQ_V6_from_22_qwen_concat_wo_resume
# 	Stage-c_pt_4-reason_embeddings-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_high_sigma_loss_reweighted
# 	Stage-c_pt_4-reason_embeddings-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_high_sigma_loss_reweighted_empty_string
# 	Stage-c_pt_4-reason_embeddings-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_high_sigma_loss_reweighted_empty_string_mock_wo_resume
# 	Stage-c_pt_4-reason_embeddings-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_high_sigma_loss_reweighted_empty_string_wo_resume
# 	Stage-c_pt_4-reason_embeddings-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_high_sigma_loss_reweighted_mock_wo_resume
# 	Stage-c_pt_4-reason_embeddings-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_high_sigma_loss_reweighted_wo_resume
# 	Stage-c_pt_4-reason_embeddings-Index-26-Size-2B-Res-720-Fps-16_hq_cooldown_from_57K
# 	Stage-c_pt_4-reason_embeddings-Index-26-Size-2B-Res-720-Fps-16_hq_cooldown_from_57K_4K_videos
# 	Stage-c_pt_4-reason_embeddings-Index-26-Size-2B-Res-720-Fps-16_hq_cooldown_from_57K_4K_videos_mock_wo_resume
# 	Stage-c_pt_4-reason_embeddings-Index-26-Size-2B-Res-720-Fps-16_hq_cooldown_from_57K_4K_videos_wo_resume
# 	Stage-c_pt_4-reason_embeddings-Index-26-Size-2B-Res-720-Fps-16_hq_cooldown_from_57K_mock_wo_resume
# 	Stage-c_pt_4-reason_embeddings-Index-26-Size-2B-Res-720-Fps-16_hq_cooldown_from_57K_wo_resume
# 	Stage-c_pt_4-reason_embeddings-Index-43-Size-14B-Res-720-Fps-16-Note-T24_HQV5_from_40_native_fps_qwen_concat
# 	Stage-c_pt_4-reason_embeddings-Index-43-Size-14B-Res-720-Fps-16-Note-T24_HQV5_from_40_native_fps_qwen_concat_loss_reweighted
# 	Stage-c_pt_4-reason_embeddings-Index-43-Size-14B-Res-720-Fps-16-Note-T24_HQV5_from_40_native_fps_qwen_concat_loss_reweighted_mock_wo_resume
# 	Stage-c_pt_4-reason_embeddings-Index-43-Size-14B-Res-720-Fps-16-Note-T24_HQV5_from_40_native_fps_qwen_concat_loss_reweighted_wo_resume
# 	Stage-c_pt_4-reason_embeddings-Index-43-Size-14B-Res-720-Fps-16-Note-T24_HQV5_from_40_native_fps_qwen_concat_mock_wo_resume
# 	Stage-c_pt_4-reason_embeddings-Index-43-Size-14B-Res-720-Fps-16-Note-T24_HQV5_from_40_native_fps_qwen_concat_wo_resume
# 	Stage-c_pt_4-reason_embeddings-Index-43-Size-14B-Res-720-Fps-16-Note-T24_HQV5_from_40_qwen_concat
# 	Stage-c_pt_4-reason_embeddings-Index-43-Size-14B-Res-720-Fps-16-Note-T24_HQV5_from_40_qwen_concat_mock_wo_resume
# 	Stage-c_pt_4-reason_embeddings-Index-43-Size-14B-Res-720-Fps-16-Note-T24_HQV5_from_40_qwen_concat_v2
# 	Stage-c_pt_4-reason_embeddings-Index-43-Size-14B-Res-720-Fps-16-Note-T24_HQV5_from_40_qwen_concat_v2_mock_wo_resume
# 	Stage-c_pt_4-reason_embeddings-Index-43-Size-14B-Res-720-Fps-16-Note-T24_HQV5_from_40_qwen_concat_v2_wo_resume
# 	Stage-c_pt_4-reason_embeddings-Index-43-Size-14B-Res-720-Fps-16-Note-T24_HQV5_from_40_qwen_concat_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_4K_cooldown_from_10K
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_4K_cooldown_from_10K_mock_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_4K_cooldown_from_10K_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_HQ_V8_cooldown_from_10K
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_HQ_V8_cooldown_from_10K_mock_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_HQ_V8_cooldown_from_10K_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_HQ_cooldown_from_10K
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_HQ_cooldown_from_10K_mock_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_HQ_cooldown_from_10K_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_high_sigma_loss_reweighted
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_high_sigma_loss_reweighted_1_1_rectified_flow_only
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_high_sigma_loss_reweighted_1_1_rectified_flow_only_debug1
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_high_sigma_loss_reweighted_1_1_rectified_flow_only_debug1_mock_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_high_sigma_loss_reweighted_1_1_rectified_flow_only_debug1_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_high_sigma_loss_reweighted_1_1_rectified_flow_only_debug2
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_high_sigma_loss_reweighted_1_1_rectified_flow_only_debug2_mock_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_high_sigma_loss_reweighted_1_1_rectified_flow_only_debug2_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_high_sigma_loss_reweighted_1_1_rectified_flow_only_debug3
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_high_sigma_loss_reweighted_1_1_rectified_flow_only_debug3_mock_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_high_sigma_loss_reweighted_1_1_rectified_flow_only_debug3_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_high_sigma_loss_reweighted_1_1_rectified_flow_only_improved
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_high_sigma_loss_reweighted_1_1_rectified_flow_only_improved2
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_high_sigma_loss_reweighted_1_1_rectified_flow_only_improved2_mock_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_high_sigma_loss_reweighted_1_1_rectified_flow_only_improved2_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_high_sigma_loss_reweighted_1_1_rectified_flow_only_improved_mock_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_high_sigma_loss_reweighted_1_1_rectified_flow_only_improved_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_high_sigma_loss_reweighted_1_1_rectified_flow_only_mock_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_high_sigma_loss_reweighted_1_1_rectified_flow_only_resume2
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_high_sigma_loss_reweighted_1_1_rectified_flow_only_resume2_mock_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_high_sigma_loss_reweighted_1_1_rectified_flow_only_resume2_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_high_sigma_loss_reweighted_1_1_rectified_flow_only_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_high_sigma_loss_reweighted_cooldown_from_10K
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_high_sigma_loss_reweighted_cooldown_from_10K_mock_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_high_sigma_loss_reweighted_cooldown_from_10K_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_high_sigma_loss_reweighted_mock_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_high_sigma_loss_reweighted_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_noise_analysis_shift2
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_noise_analysis_shift2_mock_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_noise_analysis_shift2_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_noise_analysis_shift5_contchunk
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_noise_analysis_shift5_contchunk_mock_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_noise_analysis_shift5_contchunk_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_noise_analysis_shift7
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_noise_analysis_shift7_mock_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-T2V_noise_analysis_shift7_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-rectified_flow_only_high_sigma
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-rectified_flow_only_high_sigma_mock_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-26-Size-2B-Res-720-Fps-16-Note-rectified_flow_only_high_sigma_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-43-Size-14B-Res-720-Fps-16_gcp
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-43-Size-14B-Res-720-Fps-16_gcp_mock_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-43-Size-14B-Res-720-Fps-16_gcp_resume2
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-43-Size-14B-Res-720-Fps-16_gcp_resume2_mock_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-43-Size-14B-Res-720-Fps-16_gcp_resume2_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-43-Size-14B-Res-720-Fps-16_gcp_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-43-Size-14B-Res-720-Fps-16_improved_pretraining_data_gcp
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-43-Size-14B-Res-720-Fps-16_improved_pretraining_data_gcp_mock_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-43-Size-14B-Res-720-Fps-16_improved_pretraining_data_gcp_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-43-Size-14B-Res-720-Fps-16_improved_pretraining_data_rectified_flow_gcp
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-43-Size-14B-Res-720-Fps-16_improved_pretraining_data_rectified_flow_gcp_mock_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-43-Size-14B-Res-720-Fps-16_improved_pretraining_data_rectified_flow_gcp_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-43-Size-14B-Res-720-Fps-16_resume_from_reason1p1_rectified_flow_4K_data_gcp
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-43-Size-14B-Res-720-Fps-16_resume_from_reason1p1_rectified_flow_4K_data_gcp_mock_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-43-Size-14B-Res-720-Fps-16_resume_from_reason1p1_rectified_flow_4K_data_gcp_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-43-Size-14B-Res-720-Fps-16_resume_from_reason1p1_rectified_flow_4K_data_s3
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-43-Size-14B-Res-720-Fps-16_resume_from_reason1p1_rectified_flow_4K_data_s3_mock_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-43-Size-14B-Res-720-Fps-16_resume_from_reason1p1_rectified_flow_4K_data_s3_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-43-Size-14B-Res-720-Fps-16_resume_from_reason1p1_rectified_flow_shift2
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-43-Size-14B-Res-720-Fps-16_resume_from_reason1p1_rectified_flow_shift2_mock_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-43-Size-14B-Res-720-Fps-16_resume_from_reason1p1_rectified_flow_shift2_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-43-Size-14B-Res-720-Fps-16_resume_from_reason1p1_rectified_flow_shift5
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-43-Size-14B-Res-720-Fps-16_resume_from_reason1p1_rectified_flow_shift5_high_sigma
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-43-Size-14B-Res-720-Fps-16_resume_from_reason1p1_rectified_flow_shift5_high_sigma_mock_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-43-Size-14B-Res-720-Fps-16_resume_from_reason1p1_rectified_flow_shift5_high_sigma_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-43-Size-14B-Res-720-Fps-16_resume_from_reason1p1_rectified_flow_shift5_mock_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-43-Size-14B-Res-720-Fps-16_resume_from_reason1p1_rectified_flow_shift5_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-43-Size-14B-Res-720-Fps-16_resume_from_reason1p1_rectified_flow_shift7
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-43-Size-14B-Res-720-Fps-16_resume_from_reason1p1_rectified_flow_shift7_gcp
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-43-Size-14B-Res-720-Fps-16_resume_from_reason1p1_rectified_flow_shift7_gcp_mock_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-43-Size-14B-Res-720-Fps-16_resume_from_reason1p1_rectified_flow_shift7_gcp_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-43-Size-14B-Res-720-Fps-16_resume_from_reason1p1_rectified_flow_shift7_mock_wo_resume
# 	Stage-c_pt_4-reason_embeddings-v1p1-Index-43-Size-14B-Res-720-Fps-16_resume_from_reason1p1_rectified_flow_shift7_wo_resume
# 	ac_reason_embeddings_rectified_flow_2b_256_320
# 	official_runs_text2world_401_7b_text_to_world_256res_gcp
# 	official_runs_text2world_401_7b_text_to_world_256res_s3
# 	official_runs_text2world_401_7b_text_to_world_256res_s3_mock_wo_resume
# 	official_runs_text2world_401_7b_text_to_world_256res_s3_wo_resume
# 	official_runs_text2world_402_7b_reason_1p1_text_to_world_256res_gcp
# 	official_runs_text2world_402_7b_reason_1p1_text_to_world_256res_s3
# 	official_runs_text2world_402_7b_reason_1p1_text_to_world_256res_s3_mock_wo_resume
# 	official_runs_text2world_402_7b_reason_1p1_text_to_world_256res_s3_wo_resume
# 	official_runs_text2world_403_7b_reason_1p1_text_to_world_256res_gcp
# 	official_runs_text2world_403_7b_reason_1p1_text_to_world_256res_s3
# 	official_runs_text2world_403_7b_reason_1p1_text_to_world_256res_s3_mock_wo_resume
# 	official_runs_text2world_403_7b_reason_1p1_text_to_world_256res_s3_wo_resume
# 	predict2_lora_training_2b_cosmos_nemo_assets_json
# 	predict2_lora_training_2b_cosmos_nemo_assets_txt
# 	predict2_video2world_training_14b_groot_gr1_480
# 	predict2_video2world_training_2b_cosmos_nemo_assets
# 	predict2_video2world_training_2b_groot_gr1_480
# 	weekly_finetuning_pretrainvideo_20250602_dedup_20250825
# 	weekly_finetuning_pretrainvideo_20250602_dedup_20250825_mock_wo_resume
# 	weekly_finetuning_pretrainvideo_20250602_dedup_20250825_wo_resume
# Config search path:
# 	provider=hydra, path=pkg://hydra.conf
# 	MSCConfigSource(provider=msc-universal, path=msc://)
# 	provider=schema, path=structured://

# %%
from cosmos_predict2.config import InferenceArguments

inference_samples = InferenceArguments.from_files([Path("datasets/base/bus_terminal.json")])
print(f"inference_samples: {inference_samples}")
output_videos = pipe.generate(inference_samples, Path("outputs"))

# %%
from IPython.display import Video, display

if output_videos:
    for video in output_videos:
        display(Video(video, embed=True))

# %%
asset_dir = "datasets"
prompt = "A nighttime city bus terminal gradually shifts from stillness to subtle movement. At first, multiple double-decker buses are parked under the glow of overhead lights, with a central bus labeled '87D' facing forward and stationary. As the video progresses, the bus in the middle moves ahead slowly, its headlights brightening the surrounding area and casting reflections onto adjacent vehicles. The motion creates space in the lineup, signaling activity within the otherwise quiet station. It then comes to a smooth stop, resuming its position in line. Overhead signage in Chinese characters remains illuminated, enhancing the vibrant, urban night scene."

args = {
    "inference_type": "image2world",
    "name": "bus_terminal",
    "input_path": os.path.join(asset_dir, "base/bus_terminal.jpg"),
    "prompt": prompt,
}

inference_args = InferenceArguments(**args)
output_videos = pipe.generate([inference_args], Path("outputs"))
